# %%
# Install mglearn
# !pip install mglearn -q

# Import library
import mglearn
import matplotlib.pyplot as plt
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 581.4/581.4 kB 7.0 MB/s eta 0:00:00

# %%
import mglearn
import matplotlib.pyplot as plt

from sklearn.datasets import fetch_lfw_people
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# 1. Load dataset
people = fetch_lfw_people(
    min_faces_per_person=20,
    resize=0.7
)

# 2. Data
X_people = people.data
y_people = people.target

# 3. PCA
pca = PCA(n_components=100, random_state=0)
X_pca = pca.fit_transform(X_people)

# 4. K-Means
km = KMeans(
    n_clusters=10,
    random_state=0,
    n_init=10
)

km.fit(X_pca)

# 5. Visualisasi hasil K-Means
mglearn.plots.plot_kmeans_faces(
    km,
    pca,
    X_pca,
    X_people,
    y_people,
    people.target_names
)

plt.show()

# %%
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import ward, dendrogram
from sklearn.datasets import fetch_lfw_people
from sklearn.decomposition import PCA

# Load dataset
people = fetch_lfw_people(
    min_faces_per_person=20,
    resize=0.7
)

X_people = people.data
y_people = people.target

# PCA
pca = PCA(n_components=100, random_state=0)
X_pca = pca.fit_transform(X_people)

# Hierarchical clustering dengan Ward
linkage_array = ward(X_pca)

# Plot dendrogram
plt.figure(figsize=(20, 5))

dendrogram(
    linkage_array,
    p=7,
    truncate_mode='level',
    no_labels=True
)

plt.xlabel("Sample index")
plt.ylabel("Cluster distance")

plt.show()
